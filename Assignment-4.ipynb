# %% [markdown]
# Python OOPs Questions

# %% [markdown]
# 1. What is Object-Oriented Programming (OOP)?
#
# OOP is a way of writing programs using objects that contain data and functions. It makes code easier to organize, reuse, and maintain.

# %% [markdown]
# 2. What is a class in OOP?
#
# A class is a blueprint or template used to create objects.

# %% [markdown]
# 3. What is an object in OOP?
#
# An object is an actual instance created from a class. It has real data and can perform actions.

# %% [markdown]
# 4. Difference between abstraction and encapsulation
#
# Abstraction: Hides complexity and shows only the important parts.
#
# Encapsulation: Hides data by keeping it inside a class and using methods to access it

# %% [markdown]
# What are dunder methods in Python?
#
# Dunder methods are special Python methods that start and end with double underscores, like __init__, __str__, etc. They add special behavior to classes.

# %% [markdown]
# Explain inheritance in OOP
#
# Inheritance allows one class to take features (methods and variables) from another class.

# %% [markdown]
# 7. What is polymorphism in OOP?
#
# Polymorphism means using the same function name but having different behaviors depending on the object.

# %% [markdown]
# 8. How is encapsulation achieved in Python?
#
# By using:
#
# Private variables: __var
#
# Getter and setter methods
#
# Properties

# %% [markdown]
# 9. What is a constructor in Python?
#
# A constructor is a special method __init__() that runs automatically when an object is created.

# %% [markdown]
# 10. What are class and static methods in Python?
#
# Class method: Uses @classmethod, works with the class itself.
#
# Static method: Uses @staticmethod, works like a normal function inside a class

# %% [markdown]
# 11. What is method overloading in Python?
#
# Python does not truly support method overloading, but you can mimic it using default arguments.

# %% [markdown]
# 12. What is method overriding in OOP?
#
# When a child class rewrites a method that already exists in the parent class.

# %% [markdown]
# 13. What is a property decorator in Python?
#
# @property lets you use a method like a variable and is used to control access to attributes.

# %% [markdown]
# 14. Why is polymorphism important in OOP?
#
# Because it makes code flexible and reusable—different objects can use the same method name.

# %% [markdown]
# 15. What is an abstract class in Python?
#
# A class that cannot be instantiated and contains abstract methods. Created using abc module.

# %% [markdown]
# 16. What are the advantages of OOP?
#
# Easier to reuse code
#
# Easier to maintain
#
# Helps structure large programs
#
# Supports abstraction and encapsulation

# %% [markdown]
# 17. Difference between class variable and instance variable
#
# Class variable: Shared by all objects of the class.
#
# Instance variable: Unique to each object.

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
# When a class inherits from more than one parent class.

# %% [markdown]
# 19. Purpose of __str__ and __repr__ methods
#
# __str__() – returns a readable string for users.
#
# __repr__() – returns a detailed string for developers.

# %% [markdown]
# 20. Significance of super() in Python
#
# super() allows a child class to call methods from its parent class.

# %% [markdown]
# 21. Significance of the __del__ method
#
# __del__() is a destructor that runs when an object is about to be deleted.

# %% [markdown]
# 22. Difference between @staticmethod and @classmethod
#
# Static method: No access to class or object.
#
# Class method: Has access to class through cls.

# %% [markdown]
# 23. How does polymorphism work in Python with inheritance?
#
# A child class can override a parent method, and Python decides which version to run at runtime.

# %% [markdown]
# 24. What is method chaining in Python OOP?
#
# Calling multiple methods one after another in a single line because each method returns self.

# %% [markdown]
# 25. Purpose of the __call__ method in Python
#
# It allows an object to be called like a function.

# %% [markdown]
# Practical Questions

# %%
# 1. Parent class Animal + child class Dog (method overriding)
class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

d = Dog()
d.speak()

# %%
# 2. Abstract class Shape + Circle + Rectangle
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return 3.14 * self.radius * self.radius

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width
    
    def area(self):
        return self.length * self.width

c = Circle(5)
r = Rectangle(4, 6)

print(c.area())
print(r.area())

# %%
# 3. Multi-level inheritance: Vehicle → Car → ElectricCar
class Vehicle:
    def __init__(self, type):
        self.type = type

class Car(Vehicle):
    def __init__(self, type, brand):
        super().__init__(type)
        self.brand = brand

class ElectricCar(Car):
    def __init__(self, type, brand, battery):
        super().__init__(type, brand)
        self.battery = battery

e = ElectricCar("Four Wheeler", "Tesla", "100 kWh")
print(e.type, e.brand, e.battery)

# %%
# 4. Polymorphism with Bird, Sparrow, Penguin
class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high")

class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly")

b1 = Sparrow()
b2 = Penguin()

b1.fly()
b2.fly()

# %%
# 5. Encapsulation – BankAccount
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        self.__balance += amount

    def withdraw(self, amount):
        if amount <= self.__balance:
            self.__balance -= amount

    def check_balance(self):
        return self.__balance

acc = BankAccount()
acc.deposit(500)
acc.withdraw(100)
print(acc.check_balance())

# %%
# 6. Runtime polymorphism – Instrument
class Instrument:
    def play(self):
        print("Instrument is playing")

class Guitar(Instrument):
    def play(self):
        print("Playing Guitar")

class Piano(Instrument):
    def play(self):
        print("Playing Piano")

i1 = Guitar()
i2 = Piano()

i1.play()
i2.play()

# %%
# 7. Class method + Static method
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

print(MathOperations.add_numbers(5, 3))
print(MathOperations.subtract_numbers(10, 4))

# %%
# 8. Class Person with counter
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

p1 = Person("A")
p2 = Person("B")
print(Person.total_persons())

# %%
# 9. Fraction class with str
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

f = Fraction(3, 4)
print(f)

# %%
# 10. Operator overloading for Vector addition
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

v1 = Vector(1, 2)
v2 = Vector(3, 4)
v3 = v1 + v2
print(v3.x, v3.y)

# %%
# 11. Person class with greet()
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

p = Person("John", 20)
p.greet()

# %%
# 12. Student class with average_grade()
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

s = Student("Tom", [80, 90, 70])
print(s.average_grade())

# %%
# 13. Rectangle class
class Rectangle:
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

r = Rectangle()
r.set_dimensions(5, 3)
print(r.area())

# %%
# 14. Employee → Manager (salary + bonus)
class Employee:
    def calculate_salary(self, hours, rate):
        return hours * rate

class Manager(Employee):
    def calculate_salary(self, hours, rate, bonus):
        return (hours * rate) + bonus

m = Manager()
print(m.calculate_salary(40, 20, 500))

# %%
# 15. Product Class
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity


# Example usage
p = Product("Laptop", 50000, 2)
print(p.total_price())   # Output: 100000

# %%
# 16. Animal (Abstract Class), Cow, Sheep
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass


class Cow(Animal):
    def sound(self):
        return "Moo"


class Sheep(Animal):
    def sound(self):
        return "Baa"


# Example usage
c = Cow()
s = Sheep()
print(c.sound())   # Moo
print(s.sound())   # Baa

# %%
# 17. Book Class
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}"


# Example usage
b = Book("1984", "George Orwell", 1949)
print(b.get_book_info())

# %%
# 18. House and Mansion Classes
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price


class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms


# Example usage
m = Mansion("123 Palm Street", 25000000, 12)
print(m.address)
print(m.price)
print(m.number_of_rooms)
